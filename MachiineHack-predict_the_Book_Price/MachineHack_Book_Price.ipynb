# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv('Copy of Data_Test (1).csv',encoding = 'unicode_escape')
train = pd.read_csv('Copy of Data_Train (1).csv',encoding = 'unicode_escape')

# %%
test.head(5)
# Out:
#    Title  Author  ...  Synopsis_subjectivity_score   Price
# 0   5803     748  ...                     0.451340  220.00
# 1   2120     370  ...                     0.522176  202.93
# 2   2982    4045  ...                     0.465767  299.00
# 3    189      79  ...                     0.375000  180.00
# 4   2853    1138  ...                     0.845625  965.62
#
# [5 rows x 10 columns]

# %%
import pandas_profiling
pandas_profiling.ProfileReport(train)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
train.isnull().sum()
# Out:
# Title                          0
# Author                         0
# Edition                        0
# Date                           0
# Reviews                        0
# Ratings                        0
# BookCategory                   0
# Synopsis_Polarity_score        0
# Synopsis_subjectivity_score    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Title                          0
# Author                         0
# Edition                        0
# Date                           0
# Reviews                        0
# Ratings                        0
# BookCategory                   0
# Synopsis_Polarity_score        0
# Synopsis_subjectivity_score    0
# Price                          0
# dtype: int64

# %%
loc = np.append(train['Genre'].values, test['Genre'].values, axis=0)
loc
# Out:
# array(['Action & Adventure (Books)', 'Cinema & Broadcast (Books)',
#        'International Relations', ..., 'Humour (Books)',
#        'United States History', 'Dictionaries'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
l.fit(list(set(loc)))
train['Genre']=l.transform(train['Genre'])
test['Genre']=l.transform(test['Genre'])

# %%
loc = np.append(train['BookCategory'].values, test['BookCategory'].values, axis=0)
loc
# Out:
# array(['Action & Adventure', 'Biographies, Diaries & True Accounts',
#        'Humour', ..., 'Humour', 'Biographies, Diaries & True Accounts',
#        'Language, Linguistics & Writing'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
l.fit(list(set(loc)))
train['BookCategory']=l.transform(train['BookCategory'])
test['BookCategory']=l.transform(test['BookCategory'])

# %%
loc = np.append(train['Author'].values, test['Author'].values, axis=0)
loc
# Out:
# array(['Chris Kuzneski', 'Arun Khopkar', 'Thomas Hobbes', ...,
#        'Khaled Hosseini', 'Heinz Guderian', 'Barbara Bregstein'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
l.fit(list(set(loc)))
train['Author']=l.transform(train['Author'])
test['Author']=l.transform(test['Author'])

# %%
loc = np.append(train['Title'].values, test['Title'].values, axis=0)
loc
# Out:
# array(["The Prisoner's Gold (The Hunters 3)",
#        'Guru Dutt: A Tragedy in Three Acts',
#        'Leviathan (Penguin Classics)', ...,
#        'The Kite Runner Graphic Novel',
#        'Panzer Leader (Penguin World War II Collection)',
#        'Complete Spanish Step-by-Step'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
l.fit(list(set(loc)))
train['Title']=l.transform(train['Title'])
test['Title']=l.transform(test['Title'])

# %%
loc = np.append(train['Edition'].values, test['Edition'].values, axis=0)
loc
# Out:
# array(['Paperback', 'Paperback', 'Paperback', ..., 'Paperback',
#        'Paperback', 'Paperback'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
l.fit(list(set(loc)))
train['Edition']=l.transform(train['Edition'])
test['Edition']=l.transform(test['Edition'])

# %%
import nltk
nltk.download('punkt')
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
aa=[]
from textblob import TextBlob
for i in train['Synopsis']:
  aa.append(TextBlob(i).polarity)

# %%
aaaa=[]
from textblob import TextBlob
for i in test['Synopsis']:
  aaaa.append(TextBlob(i).polarity)

# %%
train['Synopsis_Polarity_score']=aa
test['Synopsis_Polarity_score']=aaaa

# %%
aaa=[]
from textblob import TextBlob
for i in train['Synopsis']:
  aaa.append(TextBlob(i).subjectivity)

# %%
a=[]
from textblob import TextBlob
for i in test['Synopsis']:
  a.append(TextBlob(i).subjectivity)

# %%
train['Synopsis_subjectivity_score']=aaa
test['Synopsis_subjectivity_score']=a

# %%
train.head(5)
# Out:
#    Title  Author  ...  Synopsis_subjectivity_score  index_col
# 0   5803     748  ...                     0.451340          0
# 1   2120     370  ...                     0.522176          1
# 2   2982    4045  ...                     0.465767          2
# 3    189      79  ...                     0.375000          3
# 4   2853    1138  ...                     0.845625          4
#
# [5 rows x 11 columns]

# %%
max(train['Title'])
# Out:
# 6785

# %%
train.shape
# Out:
# (6237, 10)

# %%
test.head(5)
# Out:
#    Title  Author  ...  Synopsis_Polarity_score  Synopsis_subjectivity_score
# 0   5087    3769  ...                 0.175862                     0.433333
# 1   2907    1303  ...                 0.117309                     0.485630
# 2    754     887  ...                 0.255867                     0.655229
# 3   6233     166  ...                 0.284444                     0.438704
# 4   3787    3261  ...                 0.000000                     0.000000
#
# [5 rows x 9 columns]

# %%
train.dtypes
# Out:
# Title                            int64
# Author                           int64
# Edition                          int64
# Reviews                        float64
# Ratings                          int64
# Genre                            int64
# BookCategory                     int64
# Price                          float64
# Synopsis_Polarity_score        float64
# Synopsis_subjectivity_score    float64
# index_col                        int64
# dtype: object

# %%
del train['Synopsis']

# %%
del test['Synopsis']

# %%
train['Ratings']=train['Ratings'].str.replace(',', '')

# %%
train['Ratings']=train['Ratings'].astype(int)

# %%
test['Ratings']=test['Ratings'].str.replace(',', '')
test['Ratings']=test['Ratings'].astype(float)

# %%
train['Date']=train['Date'].fillna(method ='pad') 
test['Date']=test['Date'].fillna(method ='pad') 
test['Date'] = test['Date'].astype('datetime64')

# %%
train['index_col'] = train.index
test['index_col'] = test.index

# %%
from sklearn import preprocessing
from sklearn.preprocessing import normalize

X_train = train.drop("Price", axis=1)
X_train = X_train.drop("index_col", axis=1)
Y_train = train["Price"].values
X_test = test.drop("index_col", axis=1)

min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(X_train)
X_train = pd.DataFrame(np_scaled)

min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(X_test)
X_test = pd.DataFrame(np_scaled)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((6237, 9), (6237,), (1560, 9))

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Linear Regression

linreg = LinearRegression()
linreg.fit(X_train, Y_train)
Y_pred = linreg.predict(X_test)
acc_log = round(linreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# 7.16

# %%
#Support Vector Machines (SVM)
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc

# %%
#K-nearest (k-NN)
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn

# %%
# Gaussian Naive Bayes

gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
Y_pred = gaussian.predict(X_test)
acc_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)
acc_gaussian

# %%
#Perceptron
perceptron = Perceptron()
perceptron.fit(X_train, Y_train)
Y_pred = perceptron.predict(X_test)
acc_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)
acc_perceptron

# %%
# Linear SVC

linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_test)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
acc_linear_svc

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)
acc_sgd

# %%
# Decision Tree

decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree

# %%
# Random Forest

random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest

# %%
submission = pd.DataFrame({
        "index_col": test["index_col"],
        "Price":y_pred
    })
submission.to_csv('./submission.csv', index=False)
print(submission.head(10))
from google.colab import files
files.download('submission.csv')

# %%
from google.colab import files
files.download('submission.csv')
