# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3a3db2ff-cf1b-41df-998e-1f1a98fdcd31" name="files[]" multiple disabled />
#      <output id="result-3a3db2ff-cf1b-41df-998e-1f1a98fdcd31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0f28ac7320e5.csv to 0f28ac7320e5.csv
# ...

# %%
import pandas as pd
import numpy as np

# %%
#train=pd.read_csv('Train.csv')
a=pd.read_csv('Test (1).csv')
b=pd.read_csv('0f28ac7320e5.csv')

# %%
b.head(5)
# Out:
#        predict
# 0  3242.525232
# 1  3206.804362
# 2  3605.845446
# 3  3266.103942
# 4  3324.624784

# %%
b['t']=b['traffic_volume - Predicted']

# %%
a.head(5)
# Out:
#              date_time is_holiday  ...  weather_type      weather_description
# 0  2017-05-18 00:00:00       None  ...          Rain            moderate rain
# 1  2017-05-18 00:00:00       None  ...          Mist                     mist
# 2  2017-05-18 00:00:00       None  ...       Drizzle  light intensity drizzle
# 3  2017-05-18 01:00:00       None  ...          Rain     heavy intensity rain
# 4  2017-05-18 01:00:00       None  ...          Mist                     mist
#
# [5 rows x 14 columns]

# %%
b.dtypes
# Out:
# t             float64
# Unnamed: 1    float64
# dtype: object

# %%
b.t = b.t.astype(int)

# %%
a['date_time'] = pd.to_datetime(a['date_time'])

# %%
submission = pd.DataFrame({
        "date_time": a["date_time"],
        "traffic_volume":b['predict']
    })
submission.to_csv('./submission.csv', index=False)
print(submission.head(10))
# Out:
#              date_time  traffic_volume
# 0  2017-05-18 00:00:00     3597.502914
# 1  2017-05-18 00:00:00     3372.980412
# 2  2017-05-18 00:00:00     3050.249563
# 3  2017-05-18 01:00:00     3510.893577
# 4  2017-05-18 01:00:00     3274.330536
# 5  2017-05-18 02:00:00     4064.548486
# 6  2017-05-18 02:00:00     3291.630533
# 7  2017-05-18 02:00:00     2874.404740
# 8  2017-05-18 03:00:00     3767.953766
# 9  2017-05-18 03:00:00     4118.586469

# %%
from google.colab import files
files.download('submission.csv')

# %%
train.head(5)
# Out:
#              date_time is_holiday  ...  weather_description  traffic_volume
# 0  2012-10-02 09:00:00       None  ...     scattered clouds            5545
# 1  2012-10-02 10:00:00       None  ...        broken clouds            4516
# 2  2012-10-02 11:00:00       None  ...      overcast clouds            4767
# 3  2012-10-02 12:00:00       None  ...      overcast clouds            5026
# 4  2012-10-02 13:00:00       None  ...        broken clouds            4918
#
# [5 rows x 15 columns]

# %%
train['is_holiday'].unique()
# Out:
# array(['None', 'Columbus Day', 'Veterans Day', 'Thanksgiving Day',
#        'Christmas Day', 'New Years Day', 'Washingtons Birthday',
#        'Memorial Day', 'Independence Day', 'State Fair', 'Labor Day',
#        'Martin Luther King Jr Day'], dtype=object)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

train['is_holiday'] = le.fit_transform(train['is_holiday'])
a['is_holiday'] = le.fit_transform(a['is_holiday'])

# %%
train['weather_type'].unique()
# Out:
# array(['Clouds', 'Clear', 'Rain', 'Drizzle', 'Mist', 'Haze', 'Fog',
#        'Thunderstorm', 'Snow', 'Squall', 'Smoke'], dtype=object)

# %%
train['weather_type'] = le.fit_transform(train['weather_type'])
a['weather_type'] = le.fit_transform(a['weather_type'])

# %%
train['weather_description'].unique()
# Out:
# array(['scattered clouds', 'broken clouds', 'overcast clouds',
#        'sky is clear', 'few clouds', 'light rain',
#        'light intensity drizzle', 'mist', 'haze', 'fog',
#        'proximity shower rain', 'drizzle', 'moderate rain',
#        'heavy intensity rain', 'proximity thunderstorm',
#        'thunderstorm with light rain', 'proximity thunderstorm with rain',
#        'heavy snow', 'heavy intensity drizzle', 'snow',
#        'thunderstorm with heavy rain', 'freezing rain', 'shower snow',
#        'light rain and snow', 'light intensity shower rain', 'SQUALLS',
#        'thunderstorm with rain', 'proximity thunderstorm with drizzle',
#        'thunderstorm', 'Sky is Clear', 'very heavy rain',
#        'thunderstorm with light drizzle', 'light snow',
#        'thunderstorm with drizzle', 'smoke', 'shower drizzle',
#        'light shower snow', 'sleet'], dtype=object)

# %%
train['weather_description'].unique()
# Out:
# array([24,  2, 19, 27,  4, 13, 11, 17,  7,  5, 20,  3, 18,  9, 21, 35, 23,
#        10,  8, 30, 33,  6, 26, 14, 12,  0, 36, 22, 31,  1, 37, 34, 16, 32,
#        29, 25, 15, 28])

# %%
train['weather_description'] = le.fit_transform(train['weather_description'])
a['weather_description'] = le.fit_transform(a['weather_description'])

# %%
submission = pd.DataFrame({
        "weather_description": train["weather_description"],
        "weather_type":train['weather_type'],
         "is_holiday":train['is_holiday']
    })
submission.to_csv('./a.csv', index=False)
print(submission.head(10))
# Out:
#    weather_description  weather_type  is_holiday
# 0                   24             1           7
# 1                    2             1           7
# 2                   19             1           7
# 3                   19             1           7
# 4                    2             1           7
# 5                   27             0           7
# 6                   27             0           7
# 7                   27             0           7
# 8                    4             1           7
# 9                    4             1           7

# %%
from google.colab import files
files.download('a.csv')
